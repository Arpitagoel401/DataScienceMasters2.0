# %% [markdown]
# Q1. Explain GET and POST methods.

# %%
#  The GET method is used to request data from a specified resource.
# The POST method is used to submit data to be processed to a specified resource.

# %% [markdown]
# Q2. Why is request used in Flask?

# %%
# The request object is used to access incoming request data in a web application. It provides a way to interact with data sent 
# by the client (e.g., a web browser) as part of an HTTP request.

# %% [markdown]
# Q3. Why is redirect() used in Flask?

# %%
# the redirect() function is used to perform an HTTP redirect to a different URL. This function is commonly employed in web 
# applications to guide the user from one route (URL) to another

# %% [markdown]
# Q4. What are templates in Flask? Why is the render_template() function used?

# %%
# templates are used to separate the presentation logic from the application logic. Templates allow you to define the structure 
# of your HTML pages
# render_template() function in Flask is used to render HTML templates. It takes the name of the template file as its argument 
# and can also take additional keyword arguments to pass data to the template.

# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# ![2024-01-20%20%282%29.png](attachment:2024-01-20%20%282%29.png)
