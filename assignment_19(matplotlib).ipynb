# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %%
# Matplotlib is a popular plotting library for Python that enables the creation of a wide variety of static, animated, and 
# interactive visualizations in Python
# Matplotlib is widely used for data visualization because it offers a flexible and powerful platform for creating various types
# of plots and charts. Some of the key features and capabilities of Matplotlib include line plots, scatter plots, bar plots, 
# histograms, pie charts, error bars, and more.

# Line Plot: Connects data points with lines to visualize the relationship between two continuous variables.

# Scatter Plot: Displays individual data points on a 2D plane, useful for exploring relationships between variables.

# Bar Plot: Represents categorical data with bars, where the length of each bar corresponds to the value of a category.

# Histogram: Illustrates the distribution of a single variable by dividing data into bins and displaying frequencies.

# Pie Chart: Represents data in a circular graph, where wedges show proportions of the whole dataset.

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
# Scatter Plot: Displays individual data points on a 2D plane, useful for exploring relationships between variables.

import numpy as np 
import matplotlib.pyplot as plt
np.random.seed(3) 
x = 3 + np.random.normal(0, 2, 50) 
y = 3 + np.random.normal(0, 2, len(x)) 
plt.scatter(x,y)
plt.title("x vs y")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
# The subplot() function in Matplotlib is used to create multiple plots in the same figure.
import numpy as np
# For line 1: 
plt.subplot(2,2,1)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])
plt.plot(x,y)
# For line 2: 
plt.subplot(2,2,2)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])
plt.plot(x,y)
# For line 3: 
plt.subplot(2,2,3)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([10, 20, 30, 40, 50, 60])
plt.plot(x,y)
# For line 4: 
plt.subplot(2,2,4)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])
plt.plot(x,y)

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %%
# A bar plot is a type of chart that presents categorical data with rectangular bars, where the length of each bar corresponds to 
# the value of a specific category. Bar plots are useful for comparing the values of different categories or for showing the 
# distribution of a single categorical variable.

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Vertical Bar Plot
plt.figure(figsize=(4,4))
plt.bar(company, profit, color='skyblue')
plt.show()

# Horizontal Bar Plot
plt.figure(figsize=(4,4))
plt.barh(company, profit, color='lightcoral')
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %%
# A box plot is a statistical representation of the distribution of a dataset

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Combine the two datasets into a list
data = [box1, box2]

# Create a box plot
plt.boxplot(data, labels=['Box 1', 'Box 2'])
plt.title('Box Plot of box1 and box2')
plt.xlabel('Box')
plt.ylabel('Values')
plt.show()
